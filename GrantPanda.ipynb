# %%
with open("/Users/noahschutz/datascience/userssharedsdfschoolimprovement2010grants.csv", "r") as f:
    data = f.readlines()

# %%
import pandas as pd

# %% [markdown]
# ### Pandas and our file have been imported into Jupyter now.

# %%
data2 = pd.read_csv("/Users/noahschutz/datascience/userssharedsdfschoolimprovement2010grants.csv")

# %%
print(data2)
# Out:
#                                           School Name               City  \
# 0                   HOGARTH KINGEEKUK MEMORIAL SCHOOL           SAVOONGA
# 1                                     AKIACHAK SCHOOL           AKIACHAK
# 2                                      GAMBELL SCHOOL            GAMBELL
# 3                                BURCHELL HIGH SCHOOL            WASILLA
# 4                                        AKIAK SCHOOL              AKIAK
# 5                                      MIDVALLEY HIGH            WASILLA
# 6                                     TULUKSAK SCHOOL           TULUKSAK
# 7                         CAPITOL HEIGHTS JR HIGH SCH         MONTGOMERY
# 8                               LOWNDES CO MIDDLE SCH       FORT DEPOSIT
# 9                                  CENTRAL MIDDLE SCH           ROCKFORD
# 10                            BELLINGRATH JR HIGH SCH         MONTGOMERY
# 11                              HAYNEVILLE MIDDLE SCH         HAYNEVILLE
# ...

# %%
data2.loc[:,"2010/11/Award Amount"].mean
# Out:
# <bound method Series.mean of 0      $471014.00
# 1      $520579.00
# 2      $449592.00
# 3      $641184.00
# 4      $399686.00
# 5      $697703.00
# 6      $427658.00
# 7      $110544.00
# 8       $12973.00
# 9      $199828.00
# 10     $165903.00
# 11     $121657.00
# 12     $914557.00
# 13     $198953.00
# 14     $118394.00
# 15     $143238.00
# 16     $151116.00
# 17     $163619.00
# 18     $665000.00
# 19     $198728.00
# 20     $991451.00
# 21     $990135.00
# 22     $197012.00
# 23     $695000.00
# 24     $198783.00
# 25     $847003.00
# 26     $381512.00
# 27     $915959.00
# 28     $812195.00
# 29     $928654.00
#           ...
# 801    $115268.00
# 802      $5000.00
# 803      $5000.00
# 804    $650093.00
# 805    $749320.00
# 806    $928024.00
# 807    $134909.00
# 808      $5000.00
# 809    $124643.00
# 810    $567905.00
# 811      $5000.00
# 812      $1202.00
# 813    $258600.00
# 814    $481900.00
# 815    $464200.00
# 816    $450000.00
# 817    $156660.00
# ...

# %%
data2.describe()
# Out:
#              School Name          City State         District Name  \
# count                831           831   831                   831
# unique               821           424    50                   421
# top     EAST HIGH SCHOOL  PHILADELPHIA    CA  PHILADELPHIA CITY SD
# freq                   2            29    92                    27
#
#        2010/11/Award Amount  Model Selected  \
# count                   757             825
# unique                  651               4
# top                   $2.00  Transformation
# freq                     17             608
#
#                                                  Location
# count                                                 831
# unique                                                823
# top     6941 NORTH CENTRAL ST\nPORTLAND, OR 97203\n(45...
# freq                                                    3

# %%
data2
# Out:
#                                           School Name               City  \
# 0                   HOGARTH KINGEEKUK MEMORIAL SCHOOL           SAVOONGA
# 1                                     AKIACHAK SCHOOL           AKIACHAK
# 2                                      GAMBELL SCHOOL            GAMBELL
# 3                                BURCHELL HIGH SCHOOL            WASILLA
# 4                                        AKIAK SCHOOL              AKIAK
# 5                                      MIDVALLEY HIGH            WASILLA
# 6                                     TULUKSAK SCHOOL           TULUKSAK
# 7                         CAPITOL HEIGHTS JR HIGH SCH         MONTGOMERY
# 8                               LOWNDES CO MIDDLE SCH       FORT DEPOSIT
# 9                                  CENTRAL MIDDLE SCH           ROCKFORD
# 10                            BELLINGRATH JR HIGH SCH         MONTGOMERY
# 11                              HAYNEVILLE MIDDLE SCH         HAYNEVILLE
# ...

# %%
data2.shape
# Out:
# (831, 7)

# %%
data2.head()
# Out:
#                          School Name      City State  \
# 0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2                     GAMBELL SCHOOL   GAMBELL    AK
# 3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name 2010/11/Award Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT           $471014.00
# 1                     YUPIIT SCHOOL DISTRICT           $520579.00
# 2              BERING STRAIT SCHOOL DISTRICT           $449592.00
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT           $641184.00
# 4                     YUPIIT SCHOOL DISTRICT           $399686.00
#
#    Model Selected                                           Location
# 0  Transformation  200 MAIN ST\nSAVOONGA, AK 99769\n(63.6687, -17...
# 1  Transformation  AKIACHAK 51100\nAKIACHAK, AK 99551\n(60.8911, ...
# ...

# %%
data2.dtypes
# Out:
# School Name             object
# City                    object
# State                   object
# District Name           object
# 2010/11/Award Amount    object
# Model Selected          object
# Location                object
# dtype: object

# %%
data2['State'].astype(str)
# Out:
# 0      AK
# 1      AK
# 2      AK
# 3      AK
# 4      AK
# 5      AK
# 6      AK
# 7      AL
# 8      AL
# 9      AL
# 10     AL
# 11     AL
# 12     AL
# 13     AL
# 14     AL
# 15     AL
# 16     AL
# 17     AL
# 18     AR
# 19     AR
# 20     AR
# 21     AR
# 22     AR
# 23     AR
# 24     AR
# 25     AZ
# 26     AZ
# 27     AZ
# 28     AZ
# 29     AZ
#        ..
# 801    WA
# 802    WI
# 803    WI
# 804    WI
# 805    WI
# 806    WI
# 807    WI
# 808    WI
# 809    WI
# 810    WI
# 811    WI
# 812    WI
# 813    WV
# 814    WV
# 815    WV
# 816    WV
# 817    WV
# 818    WV
# 819    WV
# 820    WV
# 821    WV
# 822    WV
# 823    WV
# 824    WV
# 825    WV
# 826    WV
# 827    WV
# 828    WY
# 829    WY
# 830    WY
# Name: State, Length: 831, dtype: object

# %%
data2['State'].describe()
# Out:
# count     831
# unique     50
# top        CA
# freq       92
# Name: State, dtype: object

# %%
data2['State'].count()
# Out:
# 831

# %%
data2.rename(columns={"2010/11/Award Amount": "10-11AwardAmt"}, inplace=True)

# %%
data2.head()
# Out:
#                          School Name      City State  \
# 0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2                     GAMBELL SCHOOL   GAMBELL    AK
# 3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name 10-11AwardAmt  Model Selected  \
# 0              BERING STRAIT SCHOOL DISTRICT    $471014.00  Transformation
# 1                     YUPIIT SCHOOL DISTRICT    $520579.00  Transformation
# 2              BERING STRAIT SCHOOL DISTRICT    $449592.00  Transformation
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT    $641184.00  Transformation
# 4                     YUPIIT SCHOOL DISTRICT    $399686.00  Transformation
#
#                                             Location
# 0  200 MAIN ST\nSAVOONGA, AK 99769\n(63.6687, -17...
# 1  AKIACHAK 51100\nAKIACHAK, AK 99551\n(60.8911, ...
# ...
